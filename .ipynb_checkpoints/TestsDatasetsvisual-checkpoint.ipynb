# %% [markdown]
# Block Diagram Process

# %% [markdown]
# ![Block Diagram Visual.png](data:image/png;base64,...)

# %%
# !pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\programdata\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (1.20.3)
# Requirement already satisfied: attrs>=19.1.0 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: opencv-contrib-python in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (4.7.0.72)
# Requirement already satisfied: flatbuffers>=2.0 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: absl-py in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (3.4.3)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\programdata\anaconda3\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in c:\programdata\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.14.6)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.20)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->mediapipe) (1.16.0)

# %%
# from google.colab import drive
# drive.mount("/content/drive")
# # data_path = "/content/drive/My Drive/"

# %%
data_path = '/'

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 3059-A92C
#
#  Directory of C:\Users\conn3\OneDrive - Loughborough University\Datasets
#
# 09/06/2023  17:58    <DIR>          .
# 09/06/2023  17:58    <DIR>          ..
# 09/06/2023  17:58    <DIR>          .ipynb_checkpoints
# 09/06/2023  17:51    <DIR>          RADIATE_JPEGS1
# 04/06/2023  22:57   (1,473,485,405) RADIATE_JPEGS1.zip
# 08/06/2023  19:47         1,000,710 TestsDatasetsvisual.ipynb
#                2 File(s)  1,474,486,115 bytes
#                4 Dir(s)  306,679,713,792 bytes free

# %%
import os
from PIL import Image
def extract_word(string):
    start_index = string.find('_') + 1  # Find the index of the underscore and add 1 to exclude it
    end_index = string.find('.')  # Find the index of the dot

    if start_index < end_index and start_index > 0:
        return string[start_index:end_index]
    else:
        return None
def load_dataset(folder_path):
    dataset = []
    labels = []

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".jpg") or file.endswith(".png"):  # Add more extensions if needed
                image_path = os.path.join(root, file)
                label = os.path.basename(file)
                label = extract_word(label)
                try:
                    image = Image.open(image_path)  # Use PIL to open the image
                    dataset.append(image)
                    labels.append(label)
                except (IOError, OSError):
                    print(f"Error loading image: {image_path}")

    return dataset, labels

# Example usage
dataset_folder = data_path
images, groundlabels = load_dataset(dataset_folder)

# Access individual images and labels
for image, label in zip(images, groundlabels):
    # image.show()  # Display the image using PIL
    print(label)

# %%
images
# Out:
# []

# %%
import cv2
import mediapipe as mp
import time
import math
# from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib as plt
class FaceMeshDetector():

    def __init__(self, staticMode = False, maxFaces = 10, minDetectionCon=0.1,minTrackCon=0.5):
        self.staticMode = staticMode
        self.maxFaces = maxFaces

        self.minDetectionCon = minDetectionCon
        self.minTrackCon = minTrackCon
        self.mpDraw = mp.solutions.drawing_utils
        self.mpFaceMesh = mp.solutions.face_mesh
        self.faceMesh = self.mpFaceMesh.FaceMesh(self.maxFaces)
        #self.drawSpec = self.mpDraw.DrawingSpec()
    def findFaceMesh(self,img):
        self.imgRGB = img
        self.results = self.faceMesh.process(self.imgRGB)
        faces = []
        nodes = []
        diff = []
        ptri = [0, 0, 0]
        gtri = [0, 0, 0]
        sry = [0, 0, 0]

        true = [0,0,0]
        atrue = [0]
        ecount = [0]



        if self.results.multi_face_landmarks:

            for self.faceLms in self.results.multi_face_landmarks:
                self.mpDraw.draw_landmarks(img, self.faceLms, self.mpFaceMesh.FACEMESH_CONTOURS)
                face = []
                for id, lm in enumerate(self.faceLms.landmark):
                    #print(lm)
                    ih, iw, ic = img.shape
                    x, y, z  = int(lm.x*iw), int(lm.y*ih), int(lm.z*ic)
                    #print(id,x,y)
                    nodes.append([id,x,y])

                    face.append([x,y])
            faces.append(face)
        lmList = nodes
        if len(lmList) != 0:
            # tri = []
            # print(lmList[184],lmList[13],lmList[291])
            # mouth
            x1, y1 = lmList[184][1], lmList[184][2]
            x2, y2 = lmList[291][1], lmList[291][2]
            x3, y3 = lmList[13][1], lmList[13][2]
            cx, cy = (x1 + x2) // 2, (y1 + y2) // 2
            x4, y4 = lmList[14][1], lmList[14][2]
            x5, y5 = lmList[15][1], lmList[15][2]
            # cv2.circle(img,(x1, y1),15, (255,0,255),cv2.FILLED)
            # cv2.circle(img, (x2, y2), 15, (255, 0, 255), cv2.FILLED)
            # cv2.line(img,(x1,y1),(x3,y3),(255,0,255),3)
            # cv2.line(img,(x2,y2),(x3,y3),(255,0,255),3)
            # cv2.line(img,(x1,y1),(x2,y2),(255,0,255),3)

            # nose
            n1, m1 = lmList[6][1], lmList[6][2]
            n2, m2 = lmList[4][1], lmList[4][2]
            n3, m3 = lmList[9][1], lmList[9][2]
            # eyes
            e1, s1 = lmList[156][1], lmList[156][2]
            e2, s2 = lmList[130][1], lmList[130][2]
            e3, s3 = lmList[147][1], lmList[147][2]
            # cv2.line(img, (e1, s1), (e3, s3), (255, 0, 255), 3)
            # cv2.line(img, (e2, s2), (e3, s3), (255, 0, 255), 3)
            # cv2.line(img, (e1, s1), (e2, s2), (255, 0, 255), 3)

            e4, s4 = lmList[383][1], lmList[383][2]
            e5, s5 = lmList[359][1], lmList[359][2]
            e6, s6 = lmList[376][1], lmList[376][2]
            # cv2.line(img, (e4, s4), (e6, s6), (255, 0, 255), 3)
            # cv2.line(img, (e5, s5), (e6, s6), (255, 0, 255), 3)
            # cv2.line(img, (e4, s4), (e5, s5), (255, 0, 255), 3)
            ctri = [math.hypot(x2 - x1, y2 - y1), math.hypot(x3 - x1, y3 - y1), math.hypot(x2 - x3, y2 - y3)]
            dym = ((math.hypot(n3 - n1, m3 - m1) / math.hypot(n2 - n1, m2 - m1))) * 100
            dig = [math.hypot(n2 - n1, m2 - m1), math.hypot(n3 - n1, m3 - m1), math.hypot(n2 - n3, m2 - m3)]

            # print(ctri)
            # print(int(math.hypot(e3 - e6, s3 - s6)) / int(math.hypot(e1 - e4, s1 - s4)))
            ######HAPPINESS#####
            ### smile ###
            if len(ctri) != 0:
                diff = [(a - b) for (a, b) in zip(ctri, ptri)]

                # print(ptri)
                ptri = ctri
                gtri = ctri
                # print(diff)
                # print(n1,m1)
                sym = (math.hypot(x3 - x1, y3 - y1) / math.hypot(x2 - x3, y2 - y3)) * 100
                cv2.putText(img, f'Symmetry:{int(sym)}', (1300, 1000), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 255, 0), 3)
                if sym > 98 and sym < 102:
                    true[2] = 1
                if diff > [0, 0, 0]:
                    # print (math.hypot(x2 - x1, y2 - y1))
                    if int(m1 - y1) > int(m1 - y3) and int(m1 - y2) > int(m1 - y3):

                        # print (sym)
                        # print ("smile")
                        cv2.putText(img, f'SMILE', (1000, 1000), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 255, 0), 3)
                        true[0] = 1

                    #else:
                    #    print("no smile")

            # if length<50:
            #    cv2.circle(img,(cx,cy),15,(0,255,0),cv2.FILLED)
            ery = [math.hypot(e3 - e6, s3 - s6), math.hypot(e1 - e4, s1 - s4), math.hypot(x2 - x3, y2 - y3)]
            # print(ctri)
            ### eyes ###
            if len(ery) != 0:
                eiff = [(a - b) for (a, b) in zip(ery, sry)]

                if eiff > [0, 0, 0]:
                    # print (int(math.hypot(e3 - e6, s3 - s6)) / int(math.hypot(e1 - e4, s1 - s4)))
                    if int(math.hypot(e3 - e6, s3 - s6)) / int(math.hypot(e1 - e4, s1 - s4)) > 1.04:
                        # print (sym)
                        # print ("smile")
                        cv2.putText(img, f'EYE MOVEMENT', (300, 1000), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 255, 0), 3)
                        true[1] = 1


            ####ANGER#####
            if true == [1, 1, 0]:
                if dym > 66 and dym < 71:
                    print("Anger ")
                    cv2.putText(img, f'Anger', (900, 400), cv2.FONT_HERSHEY_COMPLEX, 2, (255, 255, 255), 3)
                    atrue = 1
                    ecount = 1

            if true == [1, 1, 1] and atrue != 1:
                cv2.putText(img, f'Happiness{int((sym*dym)/100)}', (1000, 300), cv2.FONT_HERSHEY_COMPLEX, 2, (255, 255, 255), 3)
                print("Hapiness")
                ecount = 2
            ####Contempt####
            if true == [1, 1, 0] and atrue != 1:
                cdist = math.hypot(x3 - x4, y3 - y4)
                if cdist < 20:
                    if int(math.hypot(e3 - e6, s3 - s6)) / int(math.hypot(e1 - e4, s1 - s4)) > 1.04 and int(
                            math.hypot(e3 - e6, s3 - s6)) / int(math.hypot(e1 - e4, s1 - s4)) < 9.96:
                        # print (cdist)
                        cv2.putText(img, f'Contempt{int(cdist)}', (1000, 200), cv2.FONT_HERSHEY_COMPLEX, 2, (255, 255, 255), 3)
                        print("Contempt")
                        ecount = 3
            #if true[0] = 1 and cdist < 20:
            # print(dig)
            ######DISGUST#####
            ### nose wrinkle ###
            if len(dig) != 0:
                # dis =  [(a / b) for (a, b) in zip(dig, redig)]

                # print(ptri)
                redig = dig

                # print(diff)
                # print(n1,m1)


                cv2.putText(img, f'nose Wrinkle:{int(dym)}', (1300, 900), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 255, 0), 3)
                # print (dym)

                if dym > 66 and dym < 71 and atrue != 1:
                    print("disgust")
                    cv2.putText(img, f'Disgust', (700, 300), cv2.FONT_HERSHEY_COMPLEX, 2, (255, 255, 255), 3)
                    ecount = 4

        return img, faces, nodes , ecount

def main():
    # cap = cv2.VideoCapture(data_path + 'test.avi')
    pTime = 0
    detector = FaceMeshDetector()
    listlabel = []
    for img in images:
        img = np.array(img)
      
          
        img, faces, nodes , ecount = detector.findFaceMesh(img)
        #cv2.putText(img, f'Happiness', (10, 200), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 3)
        #if len(faces )!= 0:
        # print(ecount)
        
        listlabel.append(ecount)
        cTime = time.time()
        fps = 1/(cTime - pTime)
        pTime = cTime
        cv2.putText(img, f'FPS: {int(fps)}', (20, 70), cv2.FONT_HERSHEY_PLAIN, 3, (0, 255, 0 ), 3)
        scale_percent = 60 # percent of original size
        width = int(img.shape[1] * scale_percent / 100)
        height = int(img.shape[0] * scale_percent / 100)
        dim = (width, height)
          
        # resize image
        resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

        cv2.imshow('show',resized)
        # cv2.waitKey(1)


if __name__ == "__main__":
    main()
# Out:
# Contempt
# disgust
# Contempt
# Contempt
# disgust
# disgust
# Contempt
# disgust
# disgust
# Contempt
# disgust
# disgust
# disgust
# Anger
# Anger
# Contempt
# Contempt
# Contempt
# disgust
# disgust
# Anger
# disgust
# Anger
# Anger
# Contempt
# Contempt
# Contempt
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# Hapiness
# disgust
# Anger
# disgust
# Contempt
# Contempt
# disgust
# disgust
# Contempt
# Contempt
# Contempt
# Hapiness
# disgust
# Contempt
# disgust
# disgust
# Contempt
# Hapiness
# disgust
# Anger
# disgust
# disgust
# Contempt
# disgust
# disgust
# disgust
# Contempt
# Contempt
# Contempt
# disgust
# disgust
# Contempt
# disgust
# disgust
# disgust
# Contempt
# disgust
# disgust
# Hapiness
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# Contempt
# Anger
# Anger
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# Contempt
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# Contempt
# disgust
# disgust
# disgust
# Contempt
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# Hapiness
# Anger
# Anger
# disgust
# disgust
# disgust
# Anger
# disgust
# disgust
# Anger
# disgust
# disgust
# disgust
# Contempt
# disgust
# disgust
# disgust
# disgust
# disgust
# disgust
# Contempt
# disgust
# disgust
# disgust
# disgust
# disgust
# Anger
# disgust
# disgust

# %%
for id,i in enumerate(images):
  print(id)

# %%
import torch
import torch.nn.functional as F
import mediapipe as mp
import cv2
import numpy as np

# Define the GNN model
class GNNModel(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GNNModel, self).__init__()

        # Define the message passing layer
        self.conv1 = torch.nn.Conv1d(input_dim, hidden_dim, kernel_size=1)
        self.conv2 = torch.nn.Conv1d(hidden_dim, hidden_dim, kernel_size=1)
        self.conv3 = torch.nn.Conv1d(hidden_dim, output_dim, kernel_size=1)

    def forward(self, x, edge_index):
        # Perform message passing
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.conv3(x)

        # Aggregate the results across the nodes
        x = torch.mean(x, dim=-1)

        return x

# Instantiate the GNN model
gnn = GNNModel(input_dim=3, hidden_dim=16, output_dim=8)

# Load the MediaPipe face mesh module
mp_face_mesh = mp.solutions.face_mesh.FaceMesh()
# Initialize a video capture object

tensorlist = []
for i in images:
  

    # Detect the facial landmarks in the frame
    results = mp_face_mesh.process(cv2.cvtColor(np.array(i), cv2.COLOR_BGR2RGB))

    # Check if facial landmarks were detected
    if results.multi_face_landmarks:
        # Extract the facial landmarks for the first detected face
        landmarks = results.multi_face_landmarks[0].landmark

        # Convert the landmarks to a graph
        nodes = torch.tensor([[landmark.x, landmark.y, landmark.z] for landmark in landmarks], dtype=torch.float32)
        edges = [[i, i+1] for i in range(20)]
        edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()

        # Pass the graph through the GNN model
        features = gnn(nodes.transpose(0, 1).unsqueeze(0), edge_index.unsqueeze(0))

        # Do something with the extracted features, e.g. print them
        print(features)
        tensorlist.append(features.detach().numpy().flatten())
        # Release the video capture and destroy the windows
cap.release()
cv2.destroyAllWindows()
# Out:
# tensor([[-0.1844, -0.2190,  0.1386,  0.2865, -0.0618,  0.1941,  0.0581,  0.0157]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1850, -0.2184,  0.1382,  0.2857, -0.0628,  0.1949,  0.0586,  0.0160]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1841, -0.2192,  0.1386,  0.2864, -0.0614,  0.1941,  0.0581,  0.0161]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1819, -0.2184,  0.1378,  0.2860, -0.0643,  0.1940,  0.0574,  0.0156]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1848, -0.2188,  0.1386,  0.2862, -0.0621,  0.1945,  0.0584,  0.0158]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1814, -0.2195,  0.1384,  0.2871, -0.0624,  0.1924,  0.0565,  0.0151]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1838, -0.2193,  0.1384,  0.2864, -0.0617,  0.1939,  0.0578,  0.0159]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1825, -0.2187,  0.1379,  0.2859, -0.0633,  0.1943,  0.0577,  0.0162]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1819, -0.2199,  0.1387,  0.2874, -0.0616,  0.1922,  0.0565,  0.0149]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1830, -0.2179,  0.1376,  0.2856, -0.0649,  0.1947,  0.0579,  0.0155]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1837, -0.2172,  0.1374,  0.2850, -0.0658,  0.1957,  0.0586,  0.0158]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1828, -0.2194,  0.1384,  0.2868, -0.0618,  0.1933,  0.0573,  0.0156]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1836, -0.2196,  0.1386,  0.2867, -0.0611,  0.1935,  0.0576,  0.0159]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1851, -0.2181,  0.1383,  0.2856, -0.0630,  0.1954,  0.0590,  0.0162]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1795, -0.2205,  0.1383,  0.2878, -0.0617,  0.1911,  0.0552,  0.0149]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1825, -0.2199,  0.1388,  0.2875, -0.0614,  0.1924,  0.0567,  0.0148]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1801, -0.2205,  0.1390,  0.2885, -0.0614,  0.1908,  0.0554,  0.0141]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1790, -0.2200,  0.1384,  0.2880, -0.0628,  0.1910,  0.0552,  0.0142]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1778, -0.2205,  0.1386,  0.2885, -0.0626,  0.1901,  0.0544,  0.0138]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1806, -0.2202,  0.1391,  0.2883, -0.0616,  0.1911,  0.0558,  0.0141]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1803, -0.2183,  0.1377,  0.2865, -0.0654,  0.1932,  0.0565,  0.0148]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.
],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1773, -0.2150,  0.1355,  0.2841, -0.0730,  0.1956,  0.0567,  0.0150]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1785, -0.2148,  0.1357,  0.2840, -0.0727,  0.1960,  0.0573,  0.0150]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1768, -0.2147,  0.1351,  0.2837, -0.0739,  0.1959,  0.0567,  0.0152]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1774, -0.2160,  0.1361,  0.2850, -0.0710,  0.1945,  0.0564,  0.0147]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1758, -0.2162,  0.1357,  0.2850, -0.0715,  0.1941,  0.0557,  0.0149]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1733, -0.2152,  0.1339,  0.2835, -0.0748,  0.1949,  0.0551,  0.0156]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1748, -0.2163,  0.1350,  0.2846, -0.0719,  0.1941,  0.0552,  0.0153]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1822, -0.2167,  0.1375,  0.2854, -0.0674,  0.1954,  0.0581,  0.0150]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1830, -0.2177,  0.1382,  0.2862, -0.0649,  0.1945,  0.0580,  0.0150]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1799, -0.2167,  0.1370,  0.2855, -0.0685,  0.1946,  0.0571,  0.0148]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1815, -0.2126,  0.1348,  0.2819, -0.0751,  0.1995,  0.0596,  0.0163]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1776, -0.2157,  0.1362,  0.2849, -0.0714,  0.1948,  0.0567,  0.0147]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1805, -0.2146,  0.1359,  0.2837, -0.0720,  0.1970,  0.0583,  0.0155]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1827, -0.2157,  0.1368,  0.2843, -0.0689,  0.1968,  0.0589,  0.0158]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1801, -0.2143,  0.1353,  0.2830, -0.0725,  0.1977,  0.0586,  0.0164]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1752, -0.2171,  0.1363,  0.2859, -0.0701,  0.1927,  0.0550,  0.0143]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1780, -0.2148,  0.1354,  0.2838, -0.0728,  0.1962,  0.0573,  0.0155]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1777, -0.2153,  0.1357,  0.2843, -0.0719,  0.1955,  0.0570,  0.0153]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1753, -0.2160,  0.1355,  0.2848, -0.0720,  0.1941,  0.0557,  0.0149]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1783, -0.2162,  0.1364,  0.2850, -0.0702,  0.1947,  0.0567,  0.0149]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1849, -0.2161,  0.1375,  0.2846, -0.0672,  0.1969,  0.0595,  0.0157]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1824, -0.2146,  0.1362,  0.2836, -0.0711,  0.1976,  0.0591,  0.0157]],
#        grad_fn=<MeanBackward1>)
# tensor([[-0.1782, -0.2134,  0.1342,  0.2820, -0.0752,  0.1983,  0.0583,  0.0168]],
#        grad_fn=<MeanBackward1>)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12796/13935930.py in <module>
#      59         tensorlist.append(features.detach().numpy().flatten())
#      60         # Release the video capture and destroy the windows
# ---> 61 cap.release()
#      62 cv2.destroyAllWindows()
#
# NameError: name 'cap' is not defined

# %%
import numpy as np
from sklearn.cluster import KMeans

# Convert the PyTorch tensor to a NumPy array
features = np.array(tensorlist)

# Perform k-means clustering on the features
kmeans = KMeans(n_clusters=5)
labels = kmeans.fit_predict(features)

# %%
np.array(tensorlist).shape
# Out:
# (2038, 8)

# %%
# from google.colab.patches import cv2_imshow
import mediapipe as mp
import numpy as np
cap = cv2.VideoCapture(data_path + 'test.avi')
pTime = 0
detector = FaceMeshDetector()
id = 0
listlabel = []
mp_face_mesh = mp.solutions.face_mesh.FaceMesh()
for i in images:

    img = i
    
    results = mp_face_mesh.process(cv2.cvtColor(np.array(img), cv2.COLOR_BGR2RGB))


    # Check if facial landmarks were detected
    if results.multi_face_landmarks: 
     print("yes")
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes

# %%
# from google.colab.patches import cv2_imshow

pTime = 0
detector = FaceMeshDetector()
id = 0
listlabel = []
for img in images:
    img = np.array(img)
    results = mp_face_mesh.process(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))


    # Check if facial landmarks were detected
    if results.multi_face_landmarks: 
        img, faces, nodes , ecount = detector.findFaceMesh(img)
        #cv2.putText(img, f'Happiness', (10, 200), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 255, 255), 3)
        #if len(faces )!= 0:
            #print(len(faces))
        if ecount == [0]:
          # print('None')
          ecount = 0
        print(ecount)
        listlabel.append(ecount)
        cTime = time.time()
        fps = 1/(cTime - pTime)
        pTime = cTime
        cv2.putText(img, f'Label : {int(labels[id])}', (10, 200), cv2.FONT_HERSHEY_PLAIN, 3, (0, 255, 0 ), 3)
        # print(labels[id])
        id = id+1
        # cv2_imshow(img)
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12796/1210273682.py in <module>
#      24         fps = 1/(cTime - pTime)
#      25         pTime = cTime
# ---> 26         cv2.putText(img, f'Label : {int(labels[id])}', (10, 200), cv2.FONT_HERSHEY_PLAIN, 3, (0, 255, 0 ), 3)
#      27         # print(labels[id])
#      28         id = id+1
#
# ValueError: invalid literal for int() with base 10: 'AC'

# %%
print(np.array(listlabel).shape, np.array(labels).shape)
# Out:
# (1,) (2038,)

# %%
#de-classifier
id = 0
for i in listlabel:
  if i == 0 and id > 0:
    # print(i)
    listlabel[id] = listlabel[id-1] 

  id = id+1

# %%
#magnifier
for count in range(100):
  id = 0
  for i in listlabel:
    if i == 4 and i!= 0 and id > 0:
      # print(i)
      listlabel[id-1] = listlabel[id] 

    id = id+1

# %%
#magnifier 
for count in range(100):
  id = 0
  for i in listlabel:
    if i == 2 and i!= 0 and id > 0:
      # print(i)
      listlabel[id-1] = listlabel[id] 

    id = id+1

# %%
listlabel
# Out:
# [0]

# %%
#count of all the labels 
uniquelabels =[]
countlabels = []
id = 0

for i in groundlabels:
  if i not in uniquelabels:
    uniquelabels.append(i)
for i in uniquelabels:
  count = 0
  for j in groundlabels:
    if i == j:
      count += 1
  countlabels.append(count)
  id +=1
print(uniquelabels)
print(countlabels)
# Out:
# ['AC', 'AO', 'CC', 'CO', 'DC', 'DO', 'FC', 'FO', 'HC', 'HE', 'HO', 'NC', 'NO', 'SC', 'SUR', 'SO', 'Sur']
# [128, 128, 129, 129, 129, 129, 125, 129, 129, 117, 129, 129, 129, 127, 127, 123, 2]

# %%
truelabels = []
for tag,i in enumerate(groundlabels):
    for id,j in enumerate(uniquelabels):
        if i == j:
            truelabels.append(id)
#             print(tag)

# %%
# pie_chart_fancy.py

import matplotlib.pyplot as plt

def pie_chart(uniquelabels):
    numbers = countlabels
    names = ['Neutral','','Contempt','Happiness','Disgust']
    labels = []
    for i in uniquelabels:
      labels.append(names[i])
    # Explode the first slice (Python)
    explode = (0.1, 0, 0, 0)

    fig1, ax1 = plt.subplots()
    ax1.pie(numbers, explode=explode, labels=groundlabels,
            shadow=True, startangle=90,
            autopct='%1.1f%%')
    ax1.axis('equal')
    plt.show()

pie_chart(uniquelabels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12796/3647371237.py in <module>
#      19     plt.show()
#      20
# ---> 21 pie_chart(uniquelabels)
#
# ~\AppData\Local\Temp/ipykernel_12796/3647371237.py in pie_chart(uniquelabels)
#       8     labels = []
#       9     for i in uniquelabels:
# ---> 10       labels.append(names[i])
#      11     # Explode the first slice (Python)
#      12     explode = (0.1, 0, 0, 0)
#
# TypeError: list indices must be integers or slices, not str

# %%
X = features

# %% [markdown]
# One theoretical approach for this is to utilise a clustering algorithm for generating enough clusters that are matched with the ouput of the traditional method. That can further be used for training the KNN based on the individual persons approach (can further look into how to manage the weights after looking into lifelong learning)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# plt.figure(figsize=(10,10))
plt.scatter(X[89:, 0], X[89:, 1], c=labels[89:])
plt.show()
# plt.figure(figsize=(10,10))

plt.scatter(X[89:, 0], X[89:, 1], c=truelabels[89:], marker='x')

plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
plt.figure(figsize=(10,10))
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.show()
plt.figure(figsize=(10,10))

plt.scatter(X[:, 0], X[:, 1], c=truelabels, marker='x')





plt.show()

# %%
Test = X[89:, :]
kmeans = KMeans(n_clusters=3)
pred = kmeans.fit_predict(Test)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# plt.figure(figsize=(10,10))
plt.scatter(Test[:, 0], Test[:, 1], c=pred[:])
plt.show()
# plt.figure(figsize=(10,10))

plt.scatter(X[89:, 0], X[89:, 1], c=listlabel[89:], marker='x')

plt.show()

# %%
pred
listid = []
for id,i in enumerate(pred):
  print(i,id)
  if i == 2:
      listid.append(id)

# %%
print(listid)
newlable = []

# %%
for id in listid:
  newlable.append(listlabel[id+89])

# %%
print(listlabel)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# plt.figure(figsize=(10,10))
plt.scatter(Test[listid, 0], Test[listid, 1], c=pred[listid])
plt.show()
# plt.figure(figsize=(10,10))

plt.scatter(Test[listid, 0], Test[listid, 1],c = newlable,marker= 'x' )

plt.show()

# %% [markdown]
# Unstable functions

# %%
# refernce funtion()
# check the refernce with the labels of that perticular cluster with the labels from traditional ouput
#count of all the labels 
def refernce():
  uniquelabels =[]
  countlabels = []
  id = 0

  for i in listlabel:
    if i not in uniquelabels:
      uniquelabels.append(i)
  for i in uniquelabels:
    count = 0
    for j in listlabel:
      if i == j:
        count += 1
    countlabels.append(count)
    id +=1
  print(uniquelabels)
  print(countlabels)


# k means funciton()
# run k means based on the amount of k provided 
features = np.array(tensorlist)

# Perform k-means clustering on the features
kmeans = KMeans(n_clusters=5)
labels = kmeans.fit_predict(features)
# reduction and main function()

# run a learning based system with probably a reducing circular approach for the 
# cluters and balance the ouput accordingly to see what it produces
# ### i have no idea if this would even have any benefits but it should be attempted atleast once.

# %%
id = 0 
for i in labels:
  
  count = 0
  for j in listlabel:
    if i == j:
      count += 1
  checklabels.append(count)
  id +=1

# %%
checklabels = []

# %%
for id, value in enumerate(labels):

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X,listlabel)

# %%
labels_pred = knn.predict(X)

# %%
print(labels_pred)

# %%
print(checklabels)

# %%
for i in X:
  if i[:,1] >= 0.058 and  i[:,2]<-0.270
    print()

# %%
plt.figure(figsize=(10,10))
plt.scatter(X[:, 0], X[:, 1], c=labels)





plt.show()
